# %% [markdown]
# # Simulating wait times
# To give Amir a better idea of how long he'll have to wait, you'll simulate Amir waiting 1000 times and create a histogram to show him what he should expect. Recall from the last exercise that his minimum wait time is 0 minutes and his maximum wait time is 30 minutes.
#
# As usual, pandas as pd, numpy as np, and matplotlib.pyplot as plt are loaded.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define random seed
np.random.seed(334)

# Define min and max waiting times
min_time = 0
max_time = 30

# Generate 1000 wait times between 0 and 30 mins using the random variates method of uniform distribution
wait_times = uniform.rvs(min_time, max_time, size=1000)

# Create histogram of wait_times
plt.hist(wait_times, bins=np.linspace(0, 30, 31))
plt.grid()

# Plot histogram
plt.show()

# %% [markdown]
# Superb simulating! Unless Amir figures out exactly what time each backup happens, he won't be able to time his data entry so it gets backed up sooner, but it looks like he'll wait about 15 minutes on average.
